# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns


# export_graphviz: 나무 구조 생성 및 저장 
from sklearn.tree import export_graphviz
# graphviz : 나무 구조 시각화  (.dot 확장자 파일 불러오기 등)
import graphviz
# 데이터 분할:train, test
from sklearn.model_selection import train_test_split
# 예측/회귀 Random Forest
from sklearn.ensemble import RandomForestRegressor
# 최적 모델, 파라미터 탐색
from sklearn.model_selection import GridSearchCV
# 예측/회귀 Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor


import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler

# 선형 회귀분석모델 formula(y ~ X1 + X2 + ...)
import statsmodels.formula.api as smf
# 회귀분석의 정규성 확인
from statsmodels.api import qqplot

# %%
Car_raw = pd.read_csv("/home/piai/2~5주차/2. Big Data 분석/Car.csv")
Car_raw
# Out:
#                                                    Name    Location     Price  \
# 0                                Maruti Wagon R LXI CNG      Mumbai   2682.68
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00
# 2                                          Honda Jazz V     Chennai   6898.32
# 3                                     Maruti Ertiga VDI     Chennai   9197.76
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71
# ...                                                 ...         ...       ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad       NaN
# 7249                             Volkswagen Polo GT TSI      Mumbai       NaN
# 7250                             Nissan Micra Diesel XV     Kolkata       NaN
# 7251                             Volkswagen Polo GT TSI        Pune       NaN
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi       NaN
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First   26.6 kmpl
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price
# 0      998 CC  58.16 bhp    5.0        NaN
# 1     1582 CC  126.2 bhp    5.0        NaN
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh
# 3     1248 CC  88.76 bhp    7.0        NaN
# 4     1968 CC  140.8 bhp    5.0        NaN
# ...       ...        ...    ...        ...
# 7248  1598 CC  103.6 bhp    5.0        NaN
# 7249  1197 CC  103.6 bhp    5.0        NaN
# 7250  1461 CC   63.1 bhp    5.0        NaN
# 7251  1197 CC  103.6 bhp    5.0        NaN
# 7252  2148 CC    170 bhp    5.0        NaN
#
# [7253 rows x 13 columns]

# %% [markdown]
# # 1. 데이터 전처리

# %%
# Car_raw 'null bhp' -> null값으로 대체
Car_raw['Power'] = Car_raw['Power'].replace('null bhp', pd.NA)
Car_raw.isnull().sum()
# Out:
# Name                    0
# Location                0
# Price                1053
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                 175
# Seats                  53
# New_Price            6247
# dtype: int64

# %%
# Car_raw '0.0 kmpl' -> null값으로 대체 
Car_raw['Mileage'] = Car_raw['Mileage'].replace('0.0 kmpl', pd.NA)
Car_raw.isnull().sum()
# Out:
# Name                    0
# Location                0
# Price                1053
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                83
# Engine                 46
# Power                 175
# Seats                  53
# New_Price            6247
# dtype: int64

# %% [markdown]
# ## 단위제거 (Mileage, Engine, Power, New_Price)

# %%
# 1. Mileage 열 처리 (NaN 제외하고 변환)
Car_raw['Mileage'] = (
    Car_raw['Mileage']
    .dropna()  # NaN 제외
    .astype(str)  # 문자열로 변환
    .str.extract(r'(\d+\.?\d*)')  # 숫자와 소수점 추출
    .astype(float)  # float으로 변환
)

# 2. Engine 열 처리 (NaN 제외하고 변환)
Car_raw['Engine'] = (
    Car_raw['Engine']
    .dropna()  # NaN 제외
    .astype(str)  # 문자열로 변환
    .str.extract(r'(\d+\.?\d*)')  # 숫자만 추출
    .astype(float)  # 정수로 변환 (CC는 보통 정수로 표시)
)

# 3. Power 열 처리 (NaN 제외하고 변환)
Car_raw['Power'] = (
    Car_raw['Power']
    .dropna()  # NaN 제외
    .astype(str)  # 문자열로 변환
    .str.extract(r'(\d+\.?\d*)')  # 숫자와 소수점 추출
    .astype(float)  # float으로 변환
)

# 4. New_Price 열 처리 (NaN 제외하고 변환)
Car_raw['New_Price'] = (
    Car_raw['New_Price']
    .dropna()  # NaN 제외
    .astype(str)  # 문자열로 변환
    .str.extract(r'(\d+\.?\d*)')  # 숫자와 소수점 추출
    .astype(float)  # float으로 변환
)

# %% [markdown]
# ## Name을 brand+model 로 나눔

# %%
#Name을 Brand Model 로 나눔
Car_raw['Name'] = Car_raw['Name'].str.upper()
Car_raw['Brand'] = Car_raw['Name'].str.split(' ', 1).str[0]  # 첫 단어를 브랜드로
Car_raw['Model'] = Car_raw['Name'].str.split(' ', 1).str[1]  # 나머지를 모델명으로

# %%
Car_raw = Car_raw.sort_values(by='Name')

# %% [markdown]
# ## 주행거리를 기준으로 등급 분류

# %%
# 주행거리 기준으로 등급 분류 함수 정의
def classify_kilometers(km):
    if km <= 20000:
        return 1
    elif 20000 < km <= 40000:
        return 2
    elif 40000 < km <= 60000:
        return 3
    elif 60000 < km <= 80000:
        return 4
    elif 80000 < km <= 100000:
        return 5
    else:
        return 6

# 등급 분류 열 추가
Car_raw['Kilometer_Range_Grade'] = Car_raw['Kilometers_Driven'].apply(classify_kilometers)

# %%
Car_raw
# Out:
#                                 Name   Location     Price  Year  \
# 1221  AMBASSADOR CLASSIC NOVA DIESEL    Chennai   2069.50  2003
# 6663       AUDI A3 35 TDI ATTRACTION  Ahmedabad       NaN  2014
# 398        AUDI A3 35 TDI ATTRACTION    Chennai  25293.84  2014
# 4782          AUDI A3 35 TDI PREMIUM     Mumbai  29509.48  2016
# 4989     AUDI A3 35 TDI PREMIUM PLUS     Mumbai  28972.94  2016
# ...                              ...        ...       ...   ...
# 1178       VOLVO XC60 D5 INSCRIPTION      Kochi  26336.25  2014
# 4497  VOLVO XC90 2007-2015 D5 AT AWD      Kochi  36147.20  2014
# 6384     VOLVO XC90 2007-2015 D5 AWD  Bangalore       NaN  2016
# 2401     VOLVO XC90 2007-2015 D5 AWD      Kochi  36254.50  2014
# 6659     VOLVO XC90 2007-2015 D5 AWD      Delhi       NaN  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 1221              80000    Diesel       Manual      Third    12.80  1489.0
# 6663              84004    Diesel    Automatic      First    20.38  1968.0
# 398               79271    Diesel    Automatic      First    20.38  1968.0
# 4782              20003    Diesel    Automatic      First    20.38  1968.0
# 4989              39000    Diesel    Automatic      First    20.38  1968.0
# ...                 ...       ...          ...        ...      ...     ...
# 1178              86925    Diesel    Automatic      First    11.20  2400.0
# 4497             102001    Diesel    Automatic      First    11.10  2400.0
# 6384              70000    Diesel       Manual      First    11.10  2400.0
# 2401              89230    Diesel       Manual      First    11.10  2400.0
# 6659              22230    Diesel       Manual      First    11.10  2400.0
#
#       Power  Seats  New_Price       Brand                     Model  \
# 1221   35.5    5.0        NaN  AMBASSADOR       CLASSIC NOVA DIESEL
# 6663  143.0    5.0        NaN        AUDI      A3 35 TDI ATTRACTION
# 398   143.0    5.0        NaN        AUDI      A3 35 TDI ATTRACTION
# 4782  143.0    5.0        NaN        AUDI         A3 35 TDI PREMIUM
# 4989  143.0    5.0      42.89        AUDI    A3 35 TDI PREMIUM PLUS
# ...     ...    ...        ...         ...                       ...
# 1178  215.0    5.0        NaN       VOLVO       XC60 D5 INSCRIPTION
# 4497  200.0    7.0        NaN       VOLVO  XC90 2007-2015 D5 AT AWD
# 6384  200.0    7.0        NaN       VOLVO     XC90 2007-2015 D5 AWD
# 2401  200.0    7.0        NaN       VOLVO     XC90 2007-2015 D5 AWD
# 6659  200.0    7.0        NaN       VOLVO     XC90 2007-2015 D5 AWD
#
#       Kilometer_Range_Grade
# 1221                      4
# 6663                      5
# 398                       4
# 4782                      2
# 4989                      2
# ...                     ...
# 1178                      5
# 4497                      6
# 6384                      4
# 2401                      5
# 6659                      2
#
# [7253 rows x 16 columns]

# %%
Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                    1053
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                    83
# Engine                     46
# Power                     175
# Seats                      53
# New_Price                6247
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %% [markdown]
# ## 변수별 시각화

# %%
plt.figure(figsize=(18, 12))

# Price 히스토그램
plt.subplot(3, 2, 1)
sns.histplot(Car_raw['Price'].dropna(), bins=30, kde=True)
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %%
plt.figure(figsize=(30, 15))

# Brand 막대 그래프 (Bar Chart)
plt.subplot(3, 2, 6)
sns.countplot(x=Car_raw['Brand'])
plt.title('Brand Count')

# x축 레이블 90도 회전
plt.xticks(rotation=90)

# 그래프 표시
plt.show()

# %%
plt.figure(figsize=(30, 15))

# Location 막대 그래프 (Bar Chart)
plt.subplot(3, 2, 6)
sns.countplot(x=Car_raw['Location'])
plt.title('Location Count')
# Out:
# Text(0.5, 1.0, 'Location Count')

# %%
plt.figure(figsize=(18, 12))

# Year 히스토그램
plt.subplot(3, 2, 2)
sns.histplot(Car_raw['Year'], bins=10, kde=False)
plt.title('Year Distribution')
# Out:
# Text(0.5, 1.0, 'Year Distribution')

# %%
plt.figure(figsize=(18, 12))

# Kilometer_Range_Grade 막대 그래프
plt.subplot(3, 2, 2)
sns.countplot(x='Kilometer_Range_Grade', data=Car_raw)
plt.title('Kilometer Range Grade Distribution')

# 그래프 표시
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 12))

# Fuel_Type 막대 그래프 (Bar Chart)
plt.subplot(3, 2, 4)
sns.countplot(x=Car_raw['Fuel_Type'])
plt.title('Fuel Type Count')
# Out:
# Text(0.5, 1.0, 'Fuel Type Count')

# %%
plt.figure(figsize=(18, 12))

# Transmission 막대 그래프 (Bar Chart)
plt.subplot(3, 2, 5)
sns.countplot(x=Car_raw['Transmission'])
plt.title('Transmission Type Count')
# Out:
# Text(0.5, 1.0, 'Transmission Type Count')

# %%
#Owner_Type 
plc_counts = Car_raw['Owner_Type'].value_counts().sort_index()
print(plc_counts)

fig, axs = plt.subplots(1, 2, figsize=(10, 6))

colors = sns.color_palette("pastel", len(plc_counts))

p2=sns.countplot(x='Owner_Type', data=Car_raw, ax=axs[0], palette=colors, order=plc_counts.index)
axs[0].bar_label(p2.containers[0], fmt='%d') 
axs[1].pie(plc_counts, labels=plc_counts.index, autopct='%.1f%%', colors=colors)

axs[0].set_title('Owner_Type Bar Chart', fontsize=13)
axs[1].set_title('Owner_Type Pie Chart', fontsize=13)
plt.show()
# Out:
# First             5952
# Fourth & Above      12
# Second            1152
# Third              137
# Name: Owner_Type, dtype: int64

# %%
# Mileage
sns.histplot(data=Car_raw, x='Mileage', bins=15, color="skyblue")
plt.title('Mileage', fontsize=13)
plt.xticks(np.arange(0, 40, 5))
plt.show()

# %%
# Engine
sns.histplot(data=Car_raw, x='Engine', bins=15,  color="skyblue")
plt.title('Engine', fontsize=13)
plt.xticks(np.arange(0, 6000, 1000))
plt.show()

# %%
plt.figure(figsize=(18, 12))

# Power 히스토그램
plt.subplot(3, 2, 1)
sns.histplot(Car_raw['Power'].dropna(), bins=30, kde=True)
plt.title('Power Distribution')
# Out:
# Text(0.5, 1.0, 'Power Distribution')

# %%
# Seats 
plc_counts = Car_raw['Seats'].value_counts().sort_index()
print(plc_counts)

fig, ax = plt.subplots(figsize=(8, 6))

colors = sns.color_palette("pastel", len(plc_counts))

p2 = sns.countplot(x='Seats', data=Car_raw, ax=ax, palette=colors, order=plc_counts.index)
ax.bar_label(p2.containers[0], fmt='%d') 

ax.set_title('Seats', fontsize=13)

plt.show()
# Out:
# 0.0        1
# 2.0       18
# 4.0      119
# 5.0     6047
# 6.0       38
# 7.0      796
# 8.0      170
# 9.0        3
# 10.0       8
# Name: Seats, dtype: int64

# %%
# New Price
sns.histplot(data=Car_raw, x='New_Price', bins=15,  color="skyblue")
plt.title('New_Price', fontsize=13)
plt.xticks(np.arange(0, 100, 10))
plt.show()

# %% [markdown]
# ## 결측치 대체

# %%
Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                    1053
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                    83
# Engine                     46
# Power                     175
# Seats                      53
# New_Price                6247
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %%
#Price 1053개 결측치 대체 수행(Name-주행등급 같은 애들의 중앙값으로 대체)
grouped_median = Car_raw.groupby(['Name', 'Kilometer_Range_Grade'])['Price'].transform('median')
Car_raw['Price'] = Car_raw['Price'].where(Car_raw['Price'].notna(), grouped_median)

Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                     361
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                    83
# Engine                     46
# Power                     175
# Seats                      53
# New_Price                6247
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %%
#Price 361개 결측치 대체 수행(Brand-주행등급 같은 애들의 중앙값으로 대체)
grouped_median = Car_raw.groupby(['Brand', 'Kilometer_Range_Grade'])['Price'].transform('median')
Car_raw['Price'] = Car_raw['Price'].where(Car_raw['Price'].notna(), grouped_median)

Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                       4
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                    83
# Engine                     46
# Power                     175
# Seats                      53
# New_Price                6247
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %%
# 'Price' 열에 NaN이 있는 행만 삭제 
Car_raw = Car_raw.dropna(subset=['Price'])
# 결과 확인
Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                       0
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                    83
# Engine                     46
# Power                     174
# Seats                      53
# New_Price                6243
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %%
#Mileage, power, engine, seat 같은 변수들은 출고 시 확정 되는 변수들, 이름이 같으면 값대체 수행
def fill_missing_values(df, column):
    return df[column].fillna(df.groupby('Name')[column].transform('first'))

# 결측치 대체 수행
Car_raw['Mileage'] = fill_missing_values(Car_raw, 'Mileage')
Car_raw['Power'] = fill_missing_values(Car_raw, 'Power')
Car_raw['Engine'] = fill_missing_values(Car_raw, 'Engine')
Car_raw['Seats'] = fill_missing_values(Car_raw, 'Seats')

Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                       0
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                    80
# Engine                     40
# Power                     135
# Seats                      46
# New_Price                6243
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %%
Car_raw=Car_raw.dropna(subset=['Engine','Power','Mileage'])
Car_raw.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Price                       0
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                     0
# Engine                      0
# Power                       0
# Seats                       0
# New_Price                6075
# Brand                       0
# Model                       0
# Kilometer_Range_Grade       0
# dtype: int64

# %%
Car_raw = Car_raw.drop(columns=['New_Price'])
Car_raw.isnull().sum()
# Out:
# Name                     0
# Location                 0
# Price                    0
# Year                     0
# Kilometers_Driven        0
# Fuel_Type                0
# Transmission             0
# Owner_Type               0
# Mileage                  0
# Engine                   0
# Power                    0
# Seats                    0
# Brand                    0
# Model                    0
# Kilometer_Range_Grade    0
# dtype: int64

# %%
Car_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7076 entries, 1221 to 6659
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7076 non-null   object
#  1   Location               7076 non-null   object
#  2   Price                  7076 non-null   float64
#  3   Year                   7076 non-null   int64
#  4   Kilometers_Driven      7076 non-null   int64
#  5   Fuel_Type              7076 non-null   object
#  6   Transmission           7076 non-null   object
#  7   Owner_Type             7076 non-null   object
#  8   Mileage                7076 non-null   float64
#  9   Engine                 7076 non-null   float64
#  10  Power                  7076 non-null   float64
#  11  Seats                  7076 non-null   float64
#  12  Brand                  7076 non-null   object
#  13  Model                  7076 non-null   object
#  14  Kilometer_Range_Grade  7076 non-null   int64
# dtypes: float64(5), int64(3), object(7)
# memory usage: 884.5+ KB

# %%
Car_raw.to_csv("Preprocessed_Car.csv")
Car_raw.count()
# Out:
# Name                     7076
# Location                 7076
# Price                    7076
# Year                     7076
# Kilometers_Driven        7076
# Fuel_Type                7076
# Transmission             7076
# Owner_Type               7076
# Mileage                  7076
# Engine                   7076
# Power                    7076
# Seats                    7076
# Brand                    7076
# Model                    7076
# Kilometer_Range_Grade    7076
# dtype: int64

# %% [markdown]
# ## 이상치 처리

# %%
Car_raw.boxplot(figsize=(10,4))
# Out:
# <Axes: >

# %%
# Price 이상치 확인

plt.figure(figsize=(10, 6))
sns.boxplot(x=Car_raw['Price'])
plt.title('Boxplot of Price')
plt.xlabel('Price')
plt.show()

# %%
new_titanic = Car_raw[Car_raw["Price"] > 200000 ]
new_titanic
# Out:
#                                              Name   Location     Price  Year  \
# 4079  LAND ROVER RANGE ROVER 3.0 DIESEL LWB VOGUE  Hyderabad  245273.6  2017
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 4079              25000    Diesel    Automatic      First    13.33  2993.0
#
#       Power  Seats Brand                                   Model  \
# 4079  255.0    5.0  LAND  ROVER RANGE ROVER 3.0 DIESEL LWB VOGUE
#
#       Kilometer_Range_Grade
# 4079                      2

# %%
new_titanic = Car_raw[(Car_raw["Price"] >= 150000) & (Car_raw["Price"] <= 200000)]
new_titanic
# Out:
#                             Name   Location     Price  Year  \
# 5919      JAGUAR F TYPE 5.0 V8 S  Hyderabad  153296.0  2015
# 5781  LAMBORGHINI GALLARDO COUPE      Delhi  183955.2  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 5919               8000    Petrol    Automatic      First     12.5  5000.0
# 5781               6500    Petrol    Automatic      Third      6.4  5204.0
#
#       Power  Seats        Brand            Model  Kilometer_Range_Grade
# 5919  488.1    2.0       JAGUAR  F TYPE 5.0 V8 S                      1
# 5781  560.0    2.0  LAMBORGHINI   GALLARDO COUPE                      1

# %% [markdown]
# 가격의 이상치는 모델과 브랜마다 다르므로 현재 중고차 가격과 튀는 값이 동일하므로 가격에는 이상치가 없다고 판단

# %%
# Year 이상치

plt.figure(figsize=(20, 6))
sns.boxplot(x=Car_raw['Year'])
plt.title('Boxplot of Year')
plt.xlabel('Price')
plt.show()

# %%
new_titanic = Car_raw['Year'].value_counts()
new_titanic
# Out:
# 2015    922
# 2014    920
# 2016    877
# 2013    787
# 2017    707
# 2012    670
# 2011    568
# 2010    393
# 2018    360
# 2009    237
# 2008    190
# 2007    127
# 2019    115
# 2006     76
# 2005     53
# 2004     30
# 2003     17
# 2002     13
# 2000      5
# 2001      4
# 1998      3
# 1999      2
# Name: Year, dtype: int64

# %% [markdown]
# Year 이상치는 없다고 판단.

# %%
# kilometer_Driven 이상치

plt.figure(figsize=(10, 6))
sns.boxplot(x=Car_raw['Kilometers_Driven'])
plt.title('Boxplot of Kilometers_Driven')
plt.xlabel('Kilometers_Driven')
plt.show()

# %%
new_titanic = Car_raw[(Car_raw["Kilometers_Driven"] >= 6000000)]
new_titanic
# Out:
#                            Name Location    Price  Year  Kilometers_Driven  \
# 2328  BMW X5 XDRIVE 30D M SPORT  Chennai  99642.4  2017            6500000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats Brand  \
# 2328    Diesel    Automatic      First    15.97  2993.0  258.0    5.0   BMW
#
#                       Model  Kilometer_Range_Grade
# 2328  X5 XDRIVE 30D M SPORT                      6

# %%
test =Car_raw[ Car_raw["Name"]=='BMW X5 XDRIVE 30D M SPORT']
test
# Out:
#                            Name Location     Price  Year  Kilometers_Driven  \
# 4101  BMW X5 XDRIVE 30D M SPORT  Chennai  87378.72  2016              45000
# 2328  BMW X5 XDRIVE 30D M SPORT  Chennai  99642.40  2017            6500000
# 5740  BMW X5 XDRIVE 30D M SPORT  Chennai  84312.80  2017              21000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats Brand  \
# 4101    Diesel    Automatic      First    15.97  2993.0  258.0    5.0   BMW
# 2328    Diesel    Automatic      First    15.97  2993.0  258.0    5.0   BMW
# 5740    Diesel    Automatic     Second    15.97  2993.0  258.0    5.0   BMW
#
#                       Model  Kilometer_Range_Grade
# 4101  X5 XDRIVE 30D M SPORT                      3
# 2328  X5 XDRIVE 30D M SPORT                      6
# 5740  X5 XDRIVE 30D M SPORT                      2

# %% [markdown]
# Price 는 비슷한데, 주행거리가 이상하므로 이상치 제거

# %%
Car_raw = Car_raw.drop(index=2328)

# 인덱스 재정렬 
Car_raw = Car_raw.reset_index(drop=True)
Car_raw.head()
# Out:
#                              Name   Location     Price  Year  \
# 0  AMBASSADOR CLASSIC NOVA DIESEL    Chennai   2069.50  2003
# 1       AUDI A3 35 TDI ATTRACTION  Ahmedabad  26918.78  2014
# 2       AUDI A3 35 TDI ATTRACTION    Chennai  25293.84  2014
# 3          AUDI A3 35 TDI PREMIUM     Mumbai  29509.48  2016
# 4     AUDI A3 35 TDI PREMIUM PLUS     Mumbai  28972.94  2016
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              80000    Diesel       Manual      Third    12.80  1489.0
# 1              84004    Diesel    Automatic      First    20.38  1968.0
# 2              79271    Diesel    Automatic      First    20.38  1968.0
# 3              20003    Diesel    Automatic      First    20.38  1968.0
# 4              39000    Diesel    Automatic      First    20.38  1968.0
#
#    Power  Seats       Brand                   Model  Kilometer_Range_Grade
# 0   35.5    5.0  AMBASSADOR     CLASSIC NOVA DIESEL                      4
# 1  143.0    5.0        AUDI    A3 35 TDI ATTRACTION                      5
# 2  143.0    5.0        AUDI    A3 35 TDI ATTRACTION                      4
# 3  143.0    5.0        AUDI       A3 35 TDI PREMIUM                      2
# 4  143.0    5.0        AUDI  A3 35 TDI PREMIUM PLUS                      2

# %%
# Mileage 이상치

plt.figure(figsize=(14, 10))
sns.boxplot(y=Car_raw['Mileage'])
plt.title("Boxplot of Mileage")
plt.ylabel("Mileage")
plt.show()

# %%
filtered_data = Car_raw[(Car_raw["Mileage"] >= 2) & (Car_raw["Mileage"] <= 7)]
filtered_data
# Out:
#                             Name Location     Price  Year  Kilometers_Driven  \
# 3217  LAMBORGHINI GALLARDO COUPE    Delhi  183955.2  2011               6500
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  \
# 3217    Petrol    Automatic      Third      6.4  5204.0  560.0    2.0
#
#             Brand           Model  Kilometer_Range_Grade
# 3217  LAMBORGHINI  GALLARDO COUPE                      1

# %% [markdown]
# 마일리지는 이상치가 없는 것으로 판단

# %%
# Engine 이상치
plt.figure(figsize=(14, 10))
sns.boxplot(y=Car_raw['Engine'])
plt.title("Boxplot of Engine")
plt.ylabel("Engine")
plt.show()

# %%
new_titanic = Car_raw['Engine'].value_counts()
new_titanic
# Out:
# 1197.0    734
# 1248.0    604
# 1498.0    369
# 998.0     309
# 1198.0    282
#          ...
# 2706.0      1
# 3696.0      1
# 3200.0      1
# 1468.0      1
# 1489.0      1
# Name: Engine, Length: 141, dtype: int64

# %% [markdown]
# Engine의 이상치로 판단되는 값들을 출력하여 확인한 결과, 실제 모델들의 Power와 동일한 것을 확인할 수 있었다. 즉 Power는 이상치가 없다고 판단 된다.

# %%
# Power 이상치
plt.figure(figsize=(10, 6))
sns.boxplot(x=Car_raw['Power'])
plt.title('Boxplot of Power')
plt.xlabel('Power')
plt.show()

# %%
new_titanic = Car_raw['Power'].value_counts()
new_titanic
# Out:
# 74.00     292
# 98.60     166
# 73.90     152
# 140.00    142
# 78.90     134
#          ...
# 360.00      1
# 120.69      1
# 83.11       1
# 80.90       1
# 301.73      1
# Name: Power, Length: 379, dtype: int64

# %% [markdown]
# Power의 이상치로 판단되는 값들을 출력하여 확인한 결과, 실제 모델들의 Power와 동일한 것을 확인할 수 있었다. 즉 Power는 이상치가 없다고 판단 된다.

# %%
# Seats 이상치
plt.figure(figsize=(14, 10))
sns.boxplot(y=Car_raw['Seats'])
plt.title("Boxplot of Seats")
plt.ylabel("Seat")
plt.show()

# %% [markdown]
# seats도 이상치 없다고 판단

# %% [markdown]
# ## Y축 정규화

# %%
plt.figure(figsize=(18, 12))

# Price 히스토그램
plt.subplot(3, 2, 1)
sns.histplot(Car_raw['Price'].dropna(), bins=30, kde=True)
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %%
y_log_transformed = np.log1p(Car_raw['Price'].to_numpy().reshape(-1, 1))

scaler = StandardScaler()
y_normalized = scaler.fit_transform(y_log_transformed)
y_normalized
# Out:
# array([[-1.81274634],
#        [ 1.19115916],
#        [ 1.11824661],
#        ...,
#        [ 1.53982475],
#        [ 0.64237231],
#        [ 1.34352153]])

# %%
plt.figure(figsize=(8, 6))
sns.histplot(y_normalized, bins=15, color="skyblue")
plt.title("Histogram of Normalized Log-Transformed 'Price'")
plt.xlabel("y_normalized")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # 2. 가설세우기

# %% [markdown]
# 1. Name은 가격에 영향을 주는 설명 변수일 것이다.
# 2. Location 가격에 영향을 주지 않는 설명 변수일 것이다.
# 3. Year는 가격에 영향을 주는  설명 변수일 것이다.
# 4. Kilometers_Driven은 가격에 영향을 주는 설명 변수일 것이다.
# 5. Fuel_Type는 가격에 영향을 주는 설명 변수일 것이다.
# 6. Transmission은 가격에 영향을 주는 설명 변수일 것이다.
# 7. Owner_Type는 가격에 영향을 주는 설명 변수일 것이다.
# 8. Mileage는 가격에 영향을 주는 설명 변수일 것이다. (근데, 이제… Name에 곁들어진.. 나야.. Mileage..)
# 9. Engine는 가격에 영향을 주는 설명 변수일 것이다. (근데, 이제… Name에 곁들어진.. 나야.. Engine..)
# 10. Power는 가격에 영향을 주는 설명 변수일 것이다. (근데, 이제… Name에 곁들어진.. 나야.. Power..)
# 11. Seats는 가격에 영향을 주는 설명 변수일 것이다. (근데, 이제… Name에 곁들어진.. 나야.. Seats..)
# 12. New_Price는 가격에 영향을 주지 않는 설명 변수일 것이다.

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ## 그래프

# %%
Car = Car_raw
brand = Car.groupby(by=['Brand'], as_index=True).count()

# %%
sns.pairplot(Car_raw)

# %% [markdown]
# 'Power'와 'Engine'사이에 다중 공선성 확인

# %%
plt.figure(figsize=(15, 10)) 
p5=sns.barplot(x='Brand', y='Price', data=Car_raw, ci=None)

for container in p5.containers:
    p5.bar_label(container, fmt='%d')

plt.title('Average Price by Brand') 
# x축 레이블 90도 회전
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 8)) 
p1=sns.barplot(x='Location', y='Price', data=Car_raw, ci=None)

for container in p1.containers:
    p1.bar_label(container, fmt='%d')

plt.title('Average Price by Location')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Price', data=Car_raw, marker='o')

plt.title('Price Trend Over Years')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(Car_raw['Kilometers_Driven'], Car_raw['Price'], alpha=0.3)  # alpha로 투명도 조절
plt.title('Price vs Kilometers Driven with Transparency')
plt.xlabel('Kilometers Driven')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 8)) 
p2=sns.barplot(x='Fuel_Type', y='Price', data=Car_raw, ci=None)

for container in p2.containers:
    p2.bar_label(container, fmt='%d')
    
plt.title('Average Price by Fuel_Type')    
plt.show()

# %%
plt.figure(figsize=(12, 8)) 
p3=sns.barplot(x='Transmission', y='Price', data=Car_raw, ci=None)

for container in p3.containers:
    p3.bar_label(container, fmt='%d')

plt.title('Average Price by Transmission') 
plt.show()

# %%
plt.figure(figsize=(12, 8)) 
p4=sns.barplot(x='Owner_Type', y='Price', data=Car_raw, ci=None)

for container in p4.containers:
    p4.bar_label(container, fmt='%d')

plt.title('Average Price by Owner_Type') 
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(Car_raw['Mileage'], Car_raw['Price'], alpha=0.3) 
plt.title('Price vs Mileage with Transparency')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(Car_raw['Engine'], Car_raw['Price'], alpha=0.3) 
plt.title('Price vs Engine with Transparency')
plt.xlabel('Engine')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(Car_raw['Power'], Car_raw['Price'], alpha=0.3) 
plt.title('Price vs Power with Transparency')
plt.xlabel('Power')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15, 8)) 
p7=sns.barplot(x='Seats', y='Price', data=Car_raw, ci=None)

for container in p7.containers:
    p7.bar_label(container, fmt='%d')

plt.title('Average Price by Seats')
plt.show()

# %%
plt.figure(figsize=(15, 8)) 
p6=sns.barplot(x='Kilometer_Range_Grade', y='Price', data=Car_raw, ci=None)

for container in p6.containers:
    p6.bar_label(container, fmt='%d')

plt.title('Average Price by Kilometer_Range_Grade')
plt.show()

# %%
correlation_matrix = Car_raw.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
