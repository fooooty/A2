# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns


# export_graphviz: 나무 구조 생성 및 저장 
from sklearn.tree import export_graphviz
# graphviz : 나무 구조 시각화  (.dot 확장자 파일 불러오기 등)
import graphviz
# 데이터 분할:train, test
from sklearn.model_selection import train_test_split
# 예측/회귀 Random Forest
from sklearn.ensemble import RandomForestRegressor
# 최적 모델, 파라미터 탐색
from sklearn.model_selection import GridSearchCV
# 예측/회귀 Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor


import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler

# 선형 회귀분석모델 formula(y ~ X1 + X2 + ...)
import statsmodels.formula.api as smf
# 회귀분석의 정규성 확인
from statsmodels.api import qqplot

# %%
matplotlib.rc('font',family='NanumGothic ECO')
matplotlib.rc('axes',unicode_minus=False)

# %matplotlib inline

# %%
# 실행결과 경고메시지 출력 제외
import warnings

warnings.filterwarnings('ignore')

# %%
df_raw = pd.read_csv("/home/piai/28기 임채훈/01 실습파일/2. Big Data 분석/SCALE불량.csv",encoding='euc-kr')
df_raw.head()
# Out:
#    plate_no        rolling_date scale   spec_long spec_country steel_kind  \
# 0  PLT_1001  03JAN2023:07:07:53    양품  AB/EH32-TM           미국          T
# 1  PLT_1002  03JAN2023:07:21:22    양품  AB/EH32-TM           미국          T
# 2  PLT_1003  03JAN2023:07:31:15    양품   NV-E36-TM           영국          T
# 3  PLT_1004  03JAN2023:07:41:01    양품   NV-E36-TM           영국          T
# 4  PLT_1005  03JAN2023:07:52:40    양품  BV-EH36-TM          프랑스          T
#
#    pt_thick  pt_width  pt_length hsb  ... fur_input_row fur_heat_temp  \
# 0        32      3700      15100  적용  ...            1열          1144
# 1        32      3700      15100  적용  ...            2열          1144
# 2        33      3600      19200  적용  ...            1열          1129
# 3        33      3600      19200  적용  ...            2열          1152
# 4        38      3100      13300  적용  ...            1열          1140
#
#    fur_heat_time  fur_soak_temp  fur_soak_time  fur_total_time  \
# 0            116           1133             59             259
# 1            122           1135             53             238
# 2            116           1121             55             258
# 3            125           1127             68             266
# 4            134           1128             48             246
#
#    rolling_method rolling_temp  descaling_count  work_group
# 0      TMCP(온도제어)          934                8          1조
# 1      TMCP(온도제어)          937                8          1조
# 2      TMCP(온도제어)          889                8          1조
# 3      TMCP(온도제어)          885                8          1조
# 4      TMCP(온도제어)          873                8          1조
#
# [5 rows x 21 columns]

# %%
df_raw.isnull().sum()
# Out:
# plate_no           0
# rolling_date       0
# scale              0
# spec_long          0
# spec_country       0
# steel_kind         0
# pt_thick           0
# pt_width           0
# pt_length          0
# hsb                0
# fur_no             0
# fur_input_row      0
# fur_heat_temp      0
# fur_heat_time      0
# fur_soak_temp      0
# fur_soak_time      0
# fur_total_time     0
# rolling_method     0
# rolling_temp       0
# descaling_count    0
# work_group         0
# dtype: int64

# %%
df_raw.boxplot(figsize=(10,4))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_raw['pt_thick'])
plt.title('Boxplot of Price')
plt.xlabel('pt_thick')
plt.show()

# %%
new  = df_raw[df_raw['pt_thick'] >= 100]
new
# Out:
#      plate_no        rolling_date scale  spec_long spec_country steel_kind  \
# 859  PLT_1860  09JAN2023:07:02:20    불량  JS-SM400A           일본          C
# 860  PLT_1861  09JAN2023:07:10:12    불량  JS-SM400A           일본          C
#
#      pt_thick  pt_width  pt_length hsb  ... fur_input_row fur_heat_temp  \
# 859       100      2300       9500  적용  ...            2열          1144
# 860       100      2300       9500  적용  ...            1열          1130
#
#      fur_heat_time  fur_soak_temp  fur_soak_time  fur_total_time  \
# 859             85           1150             52             219
# 860             78           1137             61             206
#
#      rolling_method rolling_temp  descaling_count  work_group
# 859        CR(제어압연)         1050                6          3조
# 860        CR(제어압연)         1037                6          3조
#
# [2 rows x 21 columns]

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(x=df_raw['pt_width'])
plt.title('Boxplot of Price')
plt.xlabel('pt_width')
plt.show()

# %%
new  = df_raw[df_raw['pt_width'] >= 4500]
new
# Out:
#      plate_no        rolling_date scale spec_long spec_country steel_kind  \
# 416  PLT_1417  06JAN2023:05:14:28    양품   BV-AH32          프랑스          C
# 419  PLT_1420  06JAN2023:05:32:53    불량   LR-AH32           영국          C
# 420  PLT_1421  06JAN2023:05:40:28    양품   LR-AH32           영국          C
# 422  PLT_1423  06JAN2023:05:54:03    불량      KR-A           한국          C
# 425  PLT_1426  06JAN2023:06:27:54    양품      LR-A           영국          C
# 426  PLT_1427  06JAN2023:06:42:19    양품      LR-A           영국          C
#
#      pt_thick  pt_width  pt_length hsb  ... fur_input_row fur_heat_temp  \
# 416        16      4600      24100  적용  ...            2열          1174
# 419        20      4500      20700  적용  ...            1열          1154
# 420        20      4500      20700  적용  ...            2열          1163
# 422        24      4500      20900  적용  ...            2열          1149
# 425        24      4600      17300  적용  ...            1열          1146
# 426        24      4600      17300  적용  ...            2열          1160
#
#      fur_heat_time  fur_soak_temp  fur_soak_time  fur_total_time  \
# 416             71           1167             58             190
# 419             77           1160             50             182
# 420             82           1160             53             191
# 422             63           1164             65             226
# 425             75           1157             52             207
# 426             77           1160             64             226
#
#      rolling_method rolling_temp  descaling_count  work_group
# 416        CR(제어압연)          933               10          2조
# 419        CR(제어압연)          961                7          2조
# 420        CR(제어압연)          959                8          2조
# 422        CR(제어압연)          976                7          2조
# 425        CR(제어압연)          957                8          2조
# 426        CR(제어압연)          956                8          2조
#
# [6 rows x 21 columns]

# %%
plt.figure(figsize=(30,6))
sns.boxplot(x=df_raw['pt_length'])
plt.title('Boxplot of Price')
plt.xlabel('pt_length')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['fur_heat_temp'])
plt.title('Boxplot of Price')
plt.xlabel('fur_heat_temp')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['fur_heat_time'])
plt.title('Boxplot of Price')
plt.xlabel('fur_heat_time')
plt.show()

# %%
new  = df_raw[df_raw['fur_heat_time'] >= 150]
new
# Out:
#      plate_no        rolling_date scale   spec_long spec_country steel_kind  \
# 565  PLT_1566  07JAN2023:05:51:14    양품  PILAC-BT33           한국          T
# 567  PLT_1568  07JAN2023:06:06:41    양품  PILAC-BT33           한국          T
# 577  PLT_1578  07JAN2023:07:52:09    양품  PILAC-BT33           한국          T
# 578  PLT_1579  07JAN2023:08:05:44    양품  PILAC-BT33           한국          T
# 651  PLT_1652  07JAN2023:20:11:51    양품        BV-A          프랑스          C
# 652  PLT_1653  07JAN2023:20:25:18    양품        KR-A           한국          C
# 653  PLT_1654  07JAN2023:20:34:49    양품        NV-A           영국          C
# 663  PLT_1664  07JAN2023:22:04:45    양품        KR-A           한국          C
# 664  PLT_1665  07JAN2023:22:13:31    양품        NV-A           영국          C
# 676  PLT_1677  08JAN2023:00:12:38    양품        NV-A           영국          C
# 677  PLT_1678  08JAN2023:00:20:34    불량        AB/A           미국          C
# 678  PLT_1679  08JAN2023:00:31:26    양품        BV-A          프랑스          C
# 679  PLT_1680  08JAN2023:00:38:37    양품        GL-A           독일          C
# 680  PLT_1681  08JAN2023:00:46:35    양품        LR-A           영국          C
# 699  PLT_1700  08JAN2023:04:00:06    양품        GL-A           독일          C
# 700  PLT_1701  08JAN2023:04:13:12    양품        KR-A           한국          C
# 701  PLT_1702  08JAN2023:04:22:24    양품        LR-A           영국          C
# 703  PLT_1704  08JAN2023:04:42:36    양품        LR-A           영국          C
#
#      pt_thick  pt_width  pt_length hsb  ... fur_input_row fur_heat_temp  \
# 565        50      1800      22200  적용  ...            1열          1158
# 567        50      2600      13100  적용  ...            1열          1152
# 577        60      2500      13300  적용  ...            1열          1142
# 578        61      2100      12300  적용  ...            2열          1143
# 651        13      3600      51700  적용  ...            1열          1169
# 652        13      3600      51700  적용  ...            1열          1169
# 653        13      3600      51700  적용  ...            1열          1169
# 663        13      3200      42700  적용  ...            1열          1160
# 664        13      3200      42700  적용  ...            1열          1160
# 676        13      2900      52700  적용  ...            1열          1154
# 677        13      2900      52500  적용  ...            2열          1157
# 678        13      2900      52500  적용  ...            2열          1157
# 679        13      2900      52500  적용  ...            2열          1157
# 680        13      2900      52500  적용  ...            2열          1157
# 699        15      3100      51800  적용  ...            1열          1156
# 700        15      3100      51800  적용  ...            1열          1156
# 701        15      3100      51800  적용  ...            1열          1156
# 703        18      3100      46200  적용  ...            2열          1155
#
#      fur_heat_time  fur_soak_temp  fur_soak_time  fur_total_time  \
# 565            156           1122             96             351
# 567            158           1134             78             315
# 577            156           1120             85             304
# 578            155           1122             87             301
# 651            156           1134             82             303
# 652            156           1134             92             307
# 653            156           1134             65             284
# 663            153           1138             71             317
# 664            153           1138             81             322
# 676            158           1144             56             308
# 677            158           1147             64             293
# 678            158           1147            101             333
# 679            158           1147             86             329
# 680            158           1147             79             316
# 699            157           1148            107             361
# 700            157           1148             83             330
# 701            157           1148             99             362
# 703            158           1151             96             321
#
#      rolling_method rolling_temp  descaling_count  work_group
# 565        CR(제어압연)          901                6          2조
# 567        CR(제어압연)          900                6          2조
# 577        CR(제어압연)          894                6          3조
# 578        CR(제어압연)          901                6          3조
# 651        CR(제어압연)          872               10          4조
# 652        CR(제어압연)          872               10          4조
# 653        CR(제어압연)          872               10          4조
# 663        CR(제어압연)          906               10          4조
# 664        CR(제어압연)          906               10          4조
# 676        CR(제어압연)          926               10          4조
# 677        CR(제어압연)          924                9          4조
# 678        CR(제어압연)          924               10          4조
# 679        CR(제어압연)          924               10          4조
# 680        CR(제어압연)          924               10          4조
# 699        CR(제어압연)          942               10          4조
# 700        CR(제어압연)          942               10          4조
# 701        CR(제어압연)          942               10          4조
# 703        CR(제어압연)          959               10          4조
#
# [18 rows x 21 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['fur_soak_temp'])
plt.title('Boxplot of Price')
plt.xlabel('fur_soak_temp')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['fur_soak_time'])
plt.title('Boxplot of Price')
plt.xlabel('fur_soak_time')
plt.show()

# %%
new  = df_raw[df_raw['fur_soak_time'] >= 140]
new
# Out:
#      plate_no        rolling_date scale    spec_long spec_country steel_kind  \
# 537  PLT_1538  07JAN2023:01:07:14    양품   NK-KD36-TM           일본          T
# 612  PLT_1613  07JAN2023:14:07:43    불량  A131-DH36TM           미국          T
# 616  PLT_1617  07JAN2023:14:43:35    양품   AB/EH36-TM           미국          T
# 617  PLT_1618  07JAN2023:14:52:54    양품   AB/EH36-TM           미국          T
# 618  PLT_1619  07JAN2023:14:58:32    양품   AB/EH36-TM           미국          T
# 620  PLT_1621  07JAN2023:15:19:34    양품       COMMON           공통          T
#
#      pt_thick  pt_width  pt_length  hsb  ... fur_input_row fur_heat_temp  \
# 537        40      2600      23400   적용  ...            2열          1166
# 612        71      3600       9200  미적용  ...            2열          1128
# 616        77      2600       7900   적용  ...            1열          1111
# 617        77      2600       7900   적용  ...            2열          1113
# 618        77      2600       7900   적용  ...            1열          1103
# 620        76      1800      16700   적용  ...            1열          1124
#
#      fur_heat_time  fur_soak_temp  fur_soak_time  fur_total_time  \
# 537             69           1118            141             289
# 612             92           1121            145             332
# 616             77           1118            144             295
# 617             71           1118            143             316
# 618             68           1122            143             300
# 620             77           1127            143             326
#
#      rolling_method rolling_temp  descaling_count  work_group
# 537      TMCP(온도제어)          818                6          2조
# 612        CR(제어압연)          859                6          3조
# 616      TMCP(온도제어)          837                6          3조
# 617      TMCP(온도제어)          842                6          3조
# 618      TMCP(온도제어)          848                6          3조
# 620        CR(제어압연)          811                6          3조
#
# [6 rows x 21 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['fur_total_time'])
plt.title('Boxplot of Price')
plt.xlabel('fur_total_time')
plt.show()

# %%
new  = df_raw[df_raw['fur_total_time'] >= 350]
new
# Out:
#      scale   spec_long spec_country steel_kind  pt_thick  pt_width  pt_length  \
# 559      0  PILAC-BT33           한국          T        50      2500      10900
# 565      0  PILAC-BT33           한국          T        50      1800      22200
# 662      0        NV-A           영국          C        12      3400      52100
# 699      0        GL-A           독일          C        15      3100      51800
# 701      0        LR-A           영국          C        15      3100      51800
#
#     hsb fur_no fur_input_row  ...  rolling_method  rolling_temp  \
# 559  적용    2호기            1열  ...        CR(제어압연)           888
# 565  적용    2호기            1열  ...        CR(제어압연)           901
# 662  적용    2호기            2열  ...        CR(제어압연)           887
# 699  적용    1호기            1열  ...        CR(제어압연)           942
# 701  적용    1호기            1열  ...        CR(제어압연)           942
#
#      descaling_count  work_group  year month  day  hour minute  second
# 559                6          2조  2023     1    7     4     43      54
# 565                6          2조  2023     1    7     5     51      14
# 662               10          4조  2023     1    7    21     59       5
# 699               10          4조  2023     1    8     4      0       6
# 701               10          4조  2023     1    8     4     22      24
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['rolling_temp'])
plt.title('Boxplot of Price')
plt.xlabel('rolling_temp')
plt.show()

# %%
new  = df_raw[df_raw['rolling_temp'] == 0]
new
# Out:
# Empty DataFrame
# Columns: [plate_no, rolling_date, scale, spec_long, spec_country, steel_kind, pt_thick, pt_width, pt_length, hsb, fur_no, fur_input_row, fur_heat_temp, fur_heat_time, fur_soak_temp, fur_soak_time, fur_total_time, rolling_method, rolling_temp, descaling_count, work_group]
# Index: []
#
# [0 rows x 21 columns]

# %%
# df_raw에서 descaling_count가 0인 행을 삭제하고 원본 데이터프레임을 업데이트
df_raw = df_raw[df_raw['rolling_temp'] != 0]

# 삭제 후 데이터프레임의 정보 확인
df_raw_info = df_raw.info()

df_raw_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   plate_no         994 non-null    object
#  1   rolling_date     994 non-null    object
#  2   scale            994 non-null    object
#  3   spec_long        994 non-null    object
#  4   spec_country     994 non-null    object
#  5   steel_kind       994 non-null    object
#  6   pt_thick         994 non-null    int64
#  7   pt_width         994 non-null    int64
#  8   pt_length        994 non-null    int64
#  9   hsb              994 non-null    object
#  10  fur_no           994 non-null    object
#  11  fur_input_row    994 non-null    object
#  12  fur_heat_temp    994 non-null    int64
#  13  fur_heat_time    994 non-null    int64
#  14  fur_soak_temp    994 non-null    int64
#  15  fur_soak_time    994 non-null    int64
#  16  fur_total_time   994 non-null    int64
#  17  rolling_method   994 non-null    object
#  18  rolling_temp     994 non-null    int64
#  19  descaling_count  994 non-null    int64
#  20  work_group       994 non-null    object
# dtypes: int64(10), object(11)
# memory usage: 170.8+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# rolling_temp가 df_raw의 열에 있다고 가정하고 히스토그램 생성
plt.figure(figsize=(10, 6))
sns.histplot(df_raw['rolling_temp'], bins=30, kde=True)
plt.title('Histogram of rolling_temp')
plt.xlabel('rolling_temp')  # 또는 'Rolling Temperature'와 같은 적절한 이름
plt.ylabel('Frequency')
plt.show()

# %%
df_raw['rolling_temp'].value_counts()
# Out:
# 993     16
# 1004    15
# 956     14
# 924     13
# 991     13
#         ..
# 854      1
# 871      1
# 868      1
# 802      1
# 943      1
# Name: rolling_temp, Length: 225, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df_raw['descaling_count'])
plt.title('Boxplot of Price')
plt.xlabel('descaling_count')
plt.show()

# %%
# rolling_date를 datetime 형식으로 변환
df_raw['rolling_date'] = pd.to_datetime(df_raw['rolling_date'], format='%d%b%Y:%H:%M:%S')

# 다시 각 날짜와 시간을 분리하여 새로운 열 추가
df_raw['year'] = df_raw['rolling_date'].dt.year
df_raw['month'] = df_raw['rolling_date'].dt.month
df_raw['day'] = df_raw['rolling_date'].dt.day
df_raw['hour'] = df_raw['rolling_date'].dt.hour
df_raw['minute'] = df_raw['rolling_date'].dt.minute
df_raw['second'] = df_raw['rolling_date'].dt.second

# 결과 확인
df_raw
# Out:
#      plate_no        rolling_date scale   spec_long spec_country steel_kind  \
# 0    PLT_1001 2023-01-03 07:07:53    양품  AB/EH32-TM           미국          T
# 1    PLT_1002 2023-01-03 07:21:22    양품  AB/EH32-TM           미국          T
# 2    PLT_1003 2023-01-03 07:31:15    양품   NV-E36-TM           영국          T
# 3    PLT_1004 2023-01-03 07:41:01    양품   NV-E36-TM           영국          T
# 4    PLT_1005 2023-01-03 07:52:40    양품  BV-EH36-TM          프랑스          T
# ..        ...                 ...   ...         ...          ...        ...
# 995  PLT_1996 2023-01-10 05:32:25    양품        BV-A          프랑스          C
# 996  PLT_1997 2023-01-10 05:39:19    양품        LR-A           영국          C
# 997  PLT_1998 2023-01-10 05:52:41    양품     AB/AH32           미국          C
# 998  PLT_1999 2023-01-10 06:01:50    양품      NV-A32           영국          C
# 999  PLT_2000 2023-01-10 06:16:27    양품      GL-A32           독일          C
#
#      pt_thick  pt_width  pt_length hsb  ... rolling_method rolling_temp  \
# 0          32      3700      15100  적용  ...     TMCP(온도제어)          934
# 1          32      3700      15100  적용  ...     TMCP(온도제어)          937
# 2          33      3600      19200  적용  ...     TMCP(온도제어)          889
# 3          33      3600      19200  적용  ...     TMCP(온도제어)          885
# 4          38      3100      13300  적용  ...     TMCP(온도제어)          873
# ..        ...       ...        ...  ..  ...            ...          ...
# 995        19      3400      41500  적용  ...       CR(제어압연)          948
# 996        19      3400      41500  적용  ...       CR(제어압연)          948
# 997        17      3400      43700  적용  ...       CR(제어압연)          948
# 998        17      3400      43700  적용  ...       CR(제어압연)          948
# 999        16      3400      54200  적용  ...       CR(제어압연)          957
#
#      descaling_count  work_group  year  month  day hour  minute  second
# 0                  8          1조  2023      1    3    7       7      53
# 1                  8          1조  2023      1    3    7      21      22
# 2                  8          1조  2023      1    3    7      31      15
# 3                  8          1조  2023      1    3    7      41       1
# 4                  8          1조  2023      1    3    7      52      40
# ..               ...         ...   ...    ...  ...  ...     ...     ...
# 995               10          4조  2023      1   10    5      32      25
# 996               10          4조  2023      1   10    5      39      19
# 997               10          4조  2023      1   10    5      52      41
# 998               10          4조  2023      1   10    6       1      50
# 999               10          4조  2023      1   10    6      16      27
#
# [1000 rows x 27 columns]

# %%
# rolling_date 열 삭제 (inplace=True)
df_raw.drop(columns=['rolling_date'], inplace=True)

# %%
df_raw.drop(columns=['plate_no'], inplace=True)

# %%
df_raw['scale'] = df_raw['scale'].apply(lambda x: 1 if x == '불량' else 0)

# %%
df_raw
# Out:
#      scale   spec_long spec_country steel_kind  pt_thick  pt_width  pt_length  \
# 0        0  AB/EH32-TM           미국          T        32      3700      15100
# 1        0  AB/EH32-TM           미국          T        32      3700      15100
# 2        0   NV-E36-TM           영국          T        33      3600      19200
# 3        0   NV-E36-TM           영국          T        33      3600      19200
# 4        0  BV-EH36-TM          프랑스          T        38      3100      13300
# ..     ...         ...          ...        ...       ...       ...        ...
# 995      0        BV-A          프랑스          C        19      3400      41500
# 996      0        LR-A           영국          C        19      3400      41500
# 997      0     AB/AH32           미국          C        17      3400      43700
# 998      0      NV-A32           영국          C        17      3400      43700
# 999      0      GL-A32           독일          C        16      3400      54200
#
#     hsb fur_no fur_input_row  ...  rolling_method  rolling_temp  \
# 0    적용    1호기            1열  ...      TMCP(온도제어)           934
# 1    적용    1호기            2열  ...      TMCP(온도제어)           937
# 2    적용    2호기            1열  ...      TMCP(온도제어)           889
# 3    적용    2호기            2열  ...      TMCP(온도제어)           885
# 4    적용    3호기            1열  ...      TMCP(온도제어)           873
# ..   ..    ...           ...  ...             ...           ...
# 995  적용    1호기            2열  ...        CR(제어압연)           948
# 996  적용    1호기            2열  ...        CR(제어압연)           948
# 997  적용    2호기            2열  ...        CR(제어압연)           948
# 998  적용    2호기            2열  ...        CR(제어압연)           948
# 999  적용    3호기            1열  ...        CR(제어압연)           957
#
#      descaling_count  work_group  year month  day  hour minute  second
# 0                  8          1조  2023     1    3     7      7      53
# 1                  8          1조  2023     1    3     7     21      22
# 2                  8          1조  2023     1    3     7     31      15
# 3                  8          1조  2023     1    3     7     41       1
# 4                  8          1조  2023     1    3     7     52      40
# ..               ...         ...   ...   ...  ...   ...    ...     ...
# 995               10          4조  2023     1   10     5     32      25
# 996               10          4조  2023     1   10     5     39      19
# 997               10          4조  2023     1   10     5     52      41
# 998               10          4조  2023     1   10     6      1      50
# 999               10          4조  2023     1   10     6     16      27
#
# [1000 rows x 25 columns]

# %%
correlation = df_raw['rolling_temp'].corr(df_raw['scale'])
print(f"Correlation between rolling_temp and target: {correlation}")

# 산점도
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(x='rolling_temp', y='scale', data=df_raw)
plt.title('Scatter plot of rolling_temp vs scale')
plt.xlabel('rolling_temp')
plt.ylabel('Target Variable')
plt.show()
# Out:
# Correlation between rolling_temp and target: 0.5113333680204876

# %%
correlation = df_raw['rolling_temp'].corr(df_raw['scale'])
print(f"Correlation between rolling_temp and scale: {correlation}")
# Out:
# Correlation between rolling_temp and scale: 0.37570398491337

# %% [markdown]
# 압연 온도와 스케일의 관계가 강하지 않음

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='rolling_temp', y='scale', data=df_raw)
plt.title('Scatter plot of rolling_temp vs scale')
plt.xlabel('rolling_temp')
plt.ylabel('Target Variable (scale)')
plt.axhline(y=df_raw['scale'].mean(), color='r', linestyle='--', label='Mean of Target (scale)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
correlation_matrix = df_raw.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix')
plt.show()
